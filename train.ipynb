# %%
from tools import image_process

# %%
image_process.convert('images')

# %% [markdown]
# ### checkpoint

# %%
from tools import image_process
import os
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sample = os.listdir('img_csv')[0]
img = np.load(os.path.join('img_csv', sample))

# %%
plt.imshow(img)

# %%
import colorizer
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import noir2color

from tools import image_process

# %matplotlib inline

# %%
in_img = image_process.load_image('/home/snowman/Desktop/tokyo_bw/29.jpg')
in_img = image_process.scale(in_img,
                             original_range=(0, 1),
                             target_range=(0, 255))

skip = 'model/skip_model/trained_model-38002'
skipp = '/home/snowman/Downloads/flower_d' \
        '/trained_model-15000'
skipper = '/home/snowman/Downloads/lastest_f_model' \
        '/trained_model-19000'
skibb = '/home/snowman/Desktop/4/trained_model-49000'
skib = '/home/snowman/Documents/ud/ml-git/saved_models' \
       '/building_model_90/trained_model-62000'
night = '/home/snowman/Documents/night_model_2/trained_model-11000'

out_img = colorizer.model_test(meta=night,
                               input_image=in_img)
plt.imshow(out_img[0])
# Out:
# INFO:tensorflow:Restoring parameters from /home/snowman/Documents/night_model_2/trained_model-11000

# %%
image_process.output_image(out_img[0],
                           '/home/snowman/Pictures/night_good_256.jpg')

# %%
import pickle
    
with open('/home/snowman/Documents/night_model/test_data.pickle', 'rb') as input_f:
    loaded = pickle.load(input_f)

# %%
loaded
# Out:
# (array(['night_set/city_bw/33.jpg', 'night_set/city_bw/40.jpg',
#         'night_set/city_bw/45.jpg', 'night_set/city_bw/52.jpg',
#         'night_set/city_bw/54.jpg', 'night_set/city_bw/66.jpg',
#         'night_set/city_bw/89.jpg', 'night_set/city_bw/90.jpg',
#         'night_set/city_bw/99.jpg', 'night_set/city_bw/141.jpg',
#         'night_set/city_bw/195.jpg', 'night_set/city_bw/231.jpg',
#         'night_set/city_bw/263.jpg', 'night_set/city_bw/267.jpg',
#         'night_set/city_bw/310.jpg', 'night_set/city_bw/315.jpg',
#         'night_set/city_bw/340.jpg', 'night_set/city_bw/344.jpg',
#         'night_set/city_bw/356.jpg', 'night_set/city_bw/400.jpg',
#         'night_set/city_bw/402.jpg', 'night_set/city_bw/419.jpg',
#         'night_set/city_bw/444.jpg'], dtype=object),
#  array(['night_set/city_np/33.jpg', 'night_set/city_np/40.jpg',
#         'night_set/city_np/45.jpg', 'night_set/city_np/52.jpg',
#         'night_set/city_np/54.jpg', 'night_set/city_np/66.jpg',
# ...
